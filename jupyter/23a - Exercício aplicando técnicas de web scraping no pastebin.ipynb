# %% [markdown]
# # 74 - Aplicando as técnicas de web scraping no site pastebin
#
# No site https://pastebin.com/ temos a direita da página um menu de seleção para códigos registrados no site, classificados por assunto.
#
# ![image.png](attachment:image.png)
#
# Nosso objetivo é o de coletar os links de colagens com temas que nos interessam.
# Exemplo: colagens com o tema JavaScript

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager

servico = Service(ChromeDriverManager().install())
navegador = webdriver.Chrome(service=servico)
